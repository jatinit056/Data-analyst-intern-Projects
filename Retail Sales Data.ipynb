# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
data = pd.read_csv("retail_sales_dataset.csv")

# %%
print(data.head())
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
descriptive_stats = data.describe()
print(descriptive_stats)
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %% [markdown]
# # Visualization:

# %%
l1 = ['A','B','C','D']
l2 = [10,20,30,40]

# %%
plt.bar(l1,l2)
plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.grid()
plt.show()

# %%
plt.plot(data.Age)

# %%
print("Recommendations:")
print("1. Focus marketing efforts on high-performing product categories.")
print("2. Implement targeted promotions during peak sales months.")
print("3. Analyze customer demographics to tailor product offerings.")
# Out:
# Recommendations:
# 1. Focus marketing efforts on high-performing product categories.
# 2. Implement targeted promotions during peak sales months.
# 3. Analyze customer demographics to tailor product offerings.
